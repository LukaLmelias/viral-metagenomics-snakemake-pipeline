# %%
#imports
import pandas as pd
import os
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in Kraken reports

# %%
def read_kraken2_reports(krakenDir):
    """
    Read and process Kraken2 reports for multiple samples and consolidate the data into a single DataFrame.

    Parameters:
    krakenDir (str): The directory containing Kraken2 report files for multiple samples.

    Returns:
    pd.DataFrame: A DataFrame containing consolidated Kraken2 report data.
    """

    kraken_df = pd.DataFrame()  # Initialize an empty DataFrame to store all samples' Kraken2 report data

    # Iterate through files in the krakenDir
    for file in os.listdir(krakenDir):
        if file.endswith("kraken2_report"):
            sample = file.split(".")[0]  # Extract the sample name from the file name

            # Read Kraken2 report per sample
            sample_kraken_df = pd.read_csv(os.path.join(krakenDir, file), sep="\t", header=None)
            sample_kraken_df.rename(columns={
                0: "coverage",
                1: "clade_fragments",
                2: "taxon_fragments",
                3: "tax_code",
                4: "taxid",
                5: "scname"
            }, inplace=True)

            # Add a 'sample' column for tracking the sample name
            sample_kraken_df['sample'] = sample

            # Update the consolidated DataFrame with sample data
            kraken_df = pd.concat([kraken_df, sample_kraken_df])

    return kraken_df

# %%
krakenDir = "/lustre/shared/wfsr-mcfa/projects/internships/luka/viral_metagenomics_pipeline/results/kraken2/results/"

# %%
kraken_df = read_kraken2_reports(krakenDir)
kraken_df.head()
# Out:
#    coverage  clade_fragments  taxon_fragments tax_code   taxid  \
# 0     32.87         21574288         21574288        U       0
# 1     67.13         44065934            15973        R       1
# 2     65.37         42905852            76410       R1  131567
# 3     64.40         42270732           135326        D    2759
# 4     63.70         41814544                0       D1   33154
#
#                  scname                                             sample
# 0          unclassified  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1                  root  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2    cellular organisms  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 3             Eukaryota  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 4          Opisthokonta  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...

# %% [markdown]
# ### link kraken viruses with host-db

# %%
#load host db viruses
hostDbPath = "/lustre/shared/wfsr-mcfa/projects/internships/luka/viral_metagenomics_pipeline/scripts/virushostdb.tsv"
hostdb_viruses = pd.read_csv(hostDbPath, sep="\t", usecols=['virus tax id', "refseq id", "virus lineage", "host name", "DISEASE"])

#select only viruses with human host
hostdb_viruses.query(" `host name` == 'Homo sapiens'", inplace= True)
human_viruses_taxids = [x for x in hostdb_viruses['virus tax id'] ]

# %%
kraken_human_viruses = kraken_df.query("taxid.isin(@human_viruses_taxids)")
kraken_human_viruses.head(40)
# Out:
#       coverage  clade_fragments  taxon_fragments tax_code    taxid  \
# 1605       0.0                3                3        S  1960046
# 1619       0.0              519                0        S    11983
# 1620       0.0              475               49       S1   122929
# 1621       0.0              376              376       S2   490039
# 1622       0.0               50               50       S2   552592
# 1681       0.0              497              497        S   194965
# 1753       0.0                1                1        S   145856
# 2017       0.0               24               24        S    11676
# 2579       0.0               52               52        S    37296
# 2591       0.0               96               96        S    10298
# 2593       0.0                1                1        S    10325
# 2651       0.0              389              389       S1    82300
# 2652       0.0              388              388       S1   256548
# 2655       0.0              511              328       S2    57579
# 2659       0.0                2                2       S2    46350
# 2660       0.0               69               69       S1    10804
# 2696       0.0                1                1       S1    10799
# 2702       0.0               88               88        S  1341019
# 2810       0.0               13               13        S  1862824
# 2824       0.0              178              178       S2  1516081
# 2836       0.0               10               10       S2  1862825
# 2965       0.0               90               90        S    10243
# 2966       0.0               31               31        S    10245
# 2967       0.0                4                4        S  2200830
# 2981       0.0                1                1       S1    10280
# 1370       0.0                1                1        S  1960046
# 1528       0.0               34               34       S1    11908
# 1531       0.0               21               21        S   338079
# 1795       0.0               76               76        S    37296
# 1799       0.0               76               76        S  1780507
# 1810       0.0                3                3        S   340907
# 1811       0.0                1                1        S    10298
# 1843       0.0               66                9       S2    57579
# 1845       0.0               42               42       S1    10804
# 1847       0.0               11               11       S1   256548
# 1859       0.0                1                1       S1    10799
# 1970       0.0              106              106        S    10243
# 1986       0.0                2                2        S   129951
# 1232       0.0                1                1        S  1960046
# 1323       0.0               18               18        S  2560318
#
#                                                  scname  \
# 1605                                    Hom-1 vesivirus
# 1619                                      Norwalk virus
# 1620                                      Norovirus GII
# 1621                                    Norovirus GII.2
# 1622                                   Norovirus GII.17
# 1681                                       Aichivirus B
# 1753                               Human picobirnavirus
# 2017                      Human immunodeficiency vir...
# 2579                           Human gammaherpesvirus 8
# 2591                           Human alphaherpesvirus 1
# 2593                        Macacine alphaherpesvirus 1
# 2651                           adeno-associated virus 5
# 2652                        Bovine adeno-associated ...
# 2655                          Adeno-associated virus...
# 2659                          Adeno-associated virus...
# 2660                           adeno-associated virus 2
# 2696                                     H-1 parvovirus
# 2702                                 Parvovirus NIH-CQV
# 2810                          Gemycircularvirus HV-GcV1
# 2824                                    MSSI2.225 virus
# 2836                          Gemycircularvirus HV-GcV2
# 2965                                       Cowpox virus
# 2966                                     Vaccinia virus
# 2967                                      Akhmeta virus
# 2981                        Molluscum contagiosum vi...
# 1370                                    Hom-1 vesivirus
# 1528                        Human T-cell leukemia vi...
# 1531                      African green monkey simia...
# 1795                           Human gammaherpesvirus 8
# 1799                          Myotis gammaherpesvirus 8
# 1810                         Papiine alphaherpesvirus 2
# 1811                           Human alphaherpesvirus 1
# 1843                          Adeno-associated virus...
# 1845                           adeno-associated virus 2
# 1847                        Bovine adeno-associated ...
# 1859                                     H-1 parvovirus
# 1970                                       Cowpox virus
# 1986                             Human mastadenovirus C
# 1232                                    Hom-1 vesivirus
# 1323                             Avian metaavulavirus 8
#
#                                                  sample
# 1605  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1619  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1620  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1621  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1622  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1681  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1753  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2017  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2579  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2591  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2593  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2651  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2652  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2655  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2659  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2660  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2696  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2702  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2810  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2824  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2836  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2965  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2966  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2967  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 2981  H7NKYDSX3_104762-001-003_81_GCCGTCGA-GTGATTAA_...
# 1370  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1528  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1531  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1795  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1799  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1810  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1811  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1843  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1845  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1847  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1859  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1970  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1986  HCFKNDSX3_104762-001-002_44_TTAATCAG-CAGATTGG_...
# 1232  HCFKNDSX3_104762-001-002_14_CGTTACCA-TAGCGTTC_...
# 1323  HCFKNDSX3_104762-001-002_14_CGTTACCA-TAGCGTTC_...

# %%
#how many unique viruses were obtained
unique_viruses = list(set(kraken_human_viruses['scname']))
len(unique_viruses)
# Out:
# 93

# %%
unique_viruses
# Out:
# ['                    Cowpox virus',
#  '        Torque teno midi virus 12',
#  '                        Adeno-associated virus - 3',
#  '                    Human orthopneumovirus',
#  '                      Human papillomavirus type 32',
#  '                    Cercopithecine betaherpesvirus 5',
#  '                    Husavirus sp.',
#  '                      H-1 parvovirus',
#  '                    Monkeypox virus',
#  '        Torque teno midi virus 6',
#  '                    Parvovirus NIH-CQV',
#  '              Hepeviridae',
#  '                      Human papillomavirus type 49',
#  '                  Salivirus A',
#  '                      Human papillomavirus 5',
#  '                      Punta Toro virus',
#  '                    Vaccinia virus',
#  '                    Norovirus GII',
#  '                    Aichi virus 1',
#  '                  Human picobirnavirus',
#  '                    Hom-1 vesivirus',
#  '                    Papiine alphaherpesvirus 2',
#  '                      Human papillomavirus 175',
#  '        Torque teno midi virus 5',
#  '                      Molluscum contagiosum virus subtype 1',
#  '                    Akhmeta virus',
#  '                    Human gammaherpesvirus 8',
#  '                      Human papillomavirus type 137',
#  '                      Sapovirus C12',
#  '        Torque teno midi virus 13',
#  '                    Gemycircularvirus sp.',
#  '                    Human betaherpesvirus 6B',
#  '                    Human betaherpesvirus 5',
#  '                    Variola virus',
#  '                    Human papillomavirus',
#  '                  Aichivirus B',
#  '                    Dengue virus 1',
#  '                    Human gammaherpesvirus 4',
#  '                  Norwalk virus',
#  '                      Gemycircularvirus HV-GcV2',
#  '                      Sapovirus Mc10',
#  '                    Norovirus GI',
#  '                    Human alphaherpesvirus 3',
#  '                    Myotis gammaherpesvirus 8',
#  '                        Norovirus GI/Hu/JP/2007/GI.P3_GI.3/Shimizu/KK2866',
#  '                    Human adenovirus 1',
#  '                    Human stool-associated circular virus NG13',
#  '                      MSSI2.225 virus',
#  '      Hudisavirus sp.',
#  '                      Bovine adeno-associated virus',
#  '                        Adeno-associated virus - 4',
#  '                      Avian metaavulavirus 8',
#  '                  Human mastadenovirus C',
#  '                    Sudan ebolavirus',
#  '                      Human T-cell leukemia virus type I',
#  '                        Norovirus GII/Hu/JP/2011/GII/Yuzawa/Gira2HS',
#  '                    Norovirus GIV',
#  '                    Human betaherpesvirus 6A',
#  '                      Norovirus GII.2',
#  '                    Macacine alphaherpesvirus 1',
#  '                      Astrovirus MLB1 HK05',
#  '                    Salivirus NG-J1',
#  '                    Human betaherpesvirus 7',
#  '                  Orthohepevirus A',
#  '                    Human cyclovirus VS5700009',
#  '                      Human papillomavirus 9',
#  '                      adeno-associated virus 2',
#  '                      Norovirus GII.17',
#  '                  Hepatovirus A',
#  '                    African green monkey simian foamy virus',
#  '                      Human papillomavirus type 92',
#  '                  Dengue virus',
#  '                    Gemycircularvirus HV-GcV1',
#  '                    Yaba monkey tumor virus',
#  '                  Human fecal virus Jorvi4',
#  '                      Human parvovirus 4 G1',
#  '                      adeno-associated virus 5',
#  '                    Human alphaherpesvirus 1',
#  '                  Murray Valley encephalitis virus',
#  '                      Monkeypox virus Zaire-96-I-16',
#  '                    Human immunodeficiency virus 1',
#  '                      NY_014 poxvirus',
#  '                    Norwalk-like virus',
#  '                      Sapovirus Hu/Dresden/pJG-Sap01/DE',
#  '                    Human circovirus VS6600022',
#  '                      Sapovirus Hu/Nagoya/NGY-1/2012/JPN',
#  '                  Cosavirus A',
#  '                      Baboon cytomegalovirus OCOM4-37',
#  '                    Astrovirus MLB1',
#  '                      Human papillomavirus type 7',
#  '                    Salivirus FHB',
#  '                        Norovirus GII/Hu/JP/2007/GII.P15_GII.15/Sapporo/HK299',
#  '                    Yichang virus']

# %% [markdown]
# ### write out the reports to file (supplementary data)

# %%
#kraken all viruses
kraken_df.to_csv("../supplimentary_data/kraken_all_viruses.csv", columns=kraken_df.columns)

#kraken human viruses
kraken_human_viruses.to_csv("../supplimentary_data/kraken_human_viruses.csv",columns=kraken_human_viruses)

#kraken unique human viruses
unique_viruses_path = "../supplimentary_data/kraken_list_of_unique_human_viruses.txt"
with open(unique_viruses_path, "w") as fn:
    for index, vir in enumerate(unique_viruses):
        fn.write(f"{vir}\n")
